# %%
import os

# %%
wordnetmap = {"keyboard": "n03085013", "pen": "n02783161", "paper": "n06255613", "monitor": "n03085219", "computer mouse": "n03793489", "knife": "n04380346", "plate": "n03960490", "spoon": "n04284002", "pan": "n03880531", "bowl": "n02880940", "apple": "n07739506", "pear": "n07767847", "banana": "n07753592", "strawberry": "n07745940", "pineapple": "n07753275", "carrot": "n07730207", "potato": "n07710616", "lettuce": "n07723559", "mushroom": "n12997919", "onion": "n07722217", "cauliflower": "n07715103", "pumpkin": "n07735510", "dog": "n02084071", "cat": "n02121808", "bird": "n01503061", "fish": "n02512053", "giraffe": "n02439033", "mosquito": "n02200198", "car": "n02958343", "bicycle": "n02834778", "bus": "n02924116", "skateboard": "n04225987", "tank": "n04389033", "shower": "n04208936", "bath": "n02808440", "towel": "n02808304", "soap": "n04254009", "hairbrush": "n03475581", "toothbrush": "n04453156", "dress": "n03236735", "trousers": "n03688605", "hat": "n03497657", "sock": "n04254777", "shoe": "n04200000", "spacesuit": "n04266375", "hammer": "n03481172", "screw": "n04154340", "drill": "n03995372", "box": "n02883344", "screwdriver": "n04154565", "tree": "n13104059", "flower": "n11669921", "grass": "n12102133", "cloud": "n09247410", "beach": "n09217230", "sun": "", "lip": "n11691857", "face": "n09618957", "foot": "n03378442", "hair": "n01900150", "heart": "n13865904", "house": "n03544360", "key": "n03613294", "sofa": "n04256520", "radiator": "n04041069", "curtain": "n03151077", "guitar": "n03467517", "piano": "n03452741", "drums": "n02803666", "microphone": "n03759954", "radio": "n04043733", "bed": "n02818832", "pillow": "n03938244", "clock": "n02694662", "closet": "n04550184", "star": "n13881644", "television": "n06278475", "book": "n02870526", "ball": "n02778669", "headphones": "n03262248", "puzzle": "n04028315", "cassette tape": "n02756977", "pencil": "n13863020", "ruler": "n04118776", "calculator": "n03483823", "adhesive tape": "n02992795", "blackboard": "n02846511", "glasses": "n04272054", "ring": "n04981658", "necklace": "n03814906", "handbag": "n02774152", "hairpin": "n03476313", "pizza": "n07873807", "bread": "n07679356", "fish": "n07577144", "spaghetti": "n07700003", "hamburger": "n07697100", "juwels": "n03139464", "vase": "n02951703", "coin": "n03954393", "sculpture": "n04306847", "dinosaur": "n01704323", "soccer": "n00478262", "tennis": "n00482298", "bowling": "n02882301", "basketball": "n02802426", "skiing": "n00440747", "balloon": "n02782093", "umbrella": "n04507155", "church": "n03028079", "camera": "n02942699", "bridge": "n02898711"}

# %%
for w in wordnetmap:
    try:
        print(w)
        print(wordnetmap[w])
        os.rename('../../data-110/'+wordnetmap[w],'../../data-110/'+w)
    except:
        continue
# Out:
# keyboard
# n03085013
# pen
# n02783161
# paper
# n06255613
# monitor
# n03085219
# computer mouse
# n03793489
# knife
# n04380346
# plate
# n03960490
# spoon
# n04284002
# pan
# n03880531
# bowl
# n02880940
# apple
# n07739506
# pear
# n07767847
# banana
# n07753592
# strawberry
# n07745940
# pineapple
# n07753275
# carrot
# n07730207
# potato
# n07710616
# lettuce
# n07723559
# mushroom
# n12997919
# onion
# n07722217
# cauliflower
# n07715103
# pumpkin
# n07735510
# dog
# n02084071
# cat
# n02121808
# bird
# n01503061
# fish
# n07577144
# giraffe
# n02439033
# mosquito
# n02200198
# car
# n02958343
# bicycle
# n02834778
# bus
# n02924116
# skateboard
# n04225987
# tank
# n04389033
# shower
# n04208936
# bath
# n02808440
# towel
# n02808304
# soap
# n04254009
# hairbrush
# n03475581
# toothbrush
# n04453156
# dress
# n03236735
# trousers
# n03688605
# hat
# n03497657
# sock
# n04254777
# shoe
# n04200000
# spacesuit
# n04266375
# hammer
# n03481172
# screw
# n04154340
# drill
# ...
